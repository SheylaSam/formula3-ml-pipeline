# %%
import pandas as pd

# ----------------------------------------
# 1. F2 Features laden (korrekter Pfad!)
# ----------------------------------------
df = pd.read_csv("../../data/f2/f2_features.csv")

# ----------------------------------------
# 2. Erste Kontrolle
# ----------------------------------------
display(df.head())
display(df.describe())
display(df['reached_f1'].value_counts())

print("Form:", df.shape)
print("Columns:", df.columns.tolist())
# Out:
#        driver  total_laps     avg_kph  avg_position  best_position  \
# 0    A. Albon      1723.0  184.954854      6.469880            1.0
# 1  A. Cordeel      1700.0  178.045965     15.458824            2.0
# 2  A. Deledda       541.0  173.171714     19.500000           12.0
# 3    A. Fuoco      1733.0  183.553476      8.541176            1.0
# 4   A. Hubert       738.0  176.557706      9.852941            1.0
#
#    avg_best_lap  avg_pos_feature_race  avg_pos_free_practice  \
# 0    101.428550              6.750000               6.454545
# 1     98.764784             14.631579              15.958333
# 2    104.020571             19.000000              21.375000
# 3    100.851103              7.368421               9.043478
# 4     97.959688              8.625000              12.444444
#
#    avg_pos_qualifying  avg_pos_sprint_race1  avg_pos_sprint_race2  \
# 0            5.761905              6.950000                   NaN
# ...

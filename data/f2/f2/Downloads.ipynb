# %%
import sys
# !{sys.executable} -m pip install pandas
# Out:
# ...
#    ---------------------------------------- 0.0/11.0 MB ? eta -:--:--
#     --------------------------------------- 0.3/11.0 MB ? eta -:--:--
#    -- ------------------------------------- 0.8/11.0 MB 2.6 MB/s eta 0:00:04
#    --- ------------------------------------ 1.0/11.0 MB 2.3 MB/s eta 0:00:05
#    ----- ---------------------------------- 1.6/11.0 MB 2.0 MB/s eta 0:00:05
#    ------ --------------------------------- 1.8/11.0 MB 1.8 MB/s eta 0:00:06
#    ------- -------------------------------- 2.1/11.0 MB 1.8 MB/s eta 0:00:05
#    -------- ------------------------------- 2.4/11.0 MB 1.8 MB/s eta 0:00:05
#    --------- ------------------------------ 2.6/11.0 MB 1.7 MB/s eta 0:00:05
#    ----------- ---------------------------- 3.1/11.0 MB 1.7 MB/s eta 0:00:05
#    ------------ --------------------------- 3.4/11.0 MB 1.7 MB/s eta 0:00:05
#    ------------- -------------------------- 3.7/11.0 MB 1.6 MB/s eta 0:00:05
# ...

# %%
import pandas as pd

df = pd.read_csv("f2/Feature-Race.csv")
df.head()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[3], line 3
#       1 import pandas as pd
# ----> 3 df = pd.read_csv("Formula 2/Feature-Race.csv")
#       4 df.head()
#
# ...
